# %%
pip install --upgrade --extra-index-url https://fiinquant.github.io/fiinquantx/simple fiinquantx
# Out:
# Looking in indexes: https://pypi.org/simple, https://fiinquant.github.io/fiinquantx/simple
# Requirement already satisfied: fiinquantx in c:\users\admin\miniconda3\lib\site-packages (0.1.37)
# Requirement already satisfied: requests in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (2.32.3)
# Requirement already satisfied: python-dateutil in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (2.9.0.post0)
# Requirement already satisfied: pandas in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (2.3.1)
# Requirement already satisfied: numpy in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (2.2.6)
# Requirement already satisfied: signalrcore in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (0.9.5)
# Requirement already satisfied: fastdtw in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (0.3.4)
# Requirement already satisfied: matplotlib in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (3.10.5)
# Requirement already satisfied: scipy in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (1.16.1)
# Requirement already satisfied: python_dotenv in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (1.1.1)
# Requirement already satisfied: scikit-learn in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (1.7.1)
# Requirement already satisfied: plotly in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (6.3.0)
# Requirement already satisfied: stumpy in c:\users\admin\miniconda3\lib\site-packages (from fiinquantx) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\miniconda3\lib\site-packages (from matplotlib->fiinquantx) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\miniconda3\lib\site-packages (from matplotlib->fiinquantx) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\miniconda3\lib\site-packages (from matplotlib->fiinquantx) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\miniconda3\lib\site-packages (from matplotlib->fiinquantx) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\miniconda3\lib\site-packages (from matplotlib->fiinquantx) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\admin\miniconda3\lib\site-packages (from matplotlib->fiinquantx) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\miniconda3\lib\site-packages (from matplotlib->fiinquantx) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\miniconda3\lib\site-packages (from python-dateutil->fiinquantx) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\miniconda3\lib\site-packages (from pandas->fiinquantx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\miniconda3\lib\site-packages (from pandas->fiinquantx) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\admin\miniconda3\lib\site-packages (from plotly->fiinquantx) (2.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\miniconda3\lib\site-packages (from requests->fiinquantx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\miniconda3\lib\site-packages (from requests->fiinquantx) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\miniconda3\lib\site-packages (from requests->fiinquantx) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\miniconda3\lib\site-packages (from requests->fiinquantx) (2025.8.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\miniconda3\lib\site-packages (from scikit-learn->fiinquantx) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\miniconda3\lib\site-packages (from scikit-learn->fiinquantx) (3.6.0)
# Requirement already satisfied: websocket-client==1.0.0 in c:\users\admin\miniconda3\lib\site-packages (from signalrcore->fiinquantx) (1.0.0)
# Requirement already satisfied: msgpack==1.0.2 in c:\users\admin\miniconda3\lib\site-packages (from signalrcore->fiinquantx) (1.0.2)
# Requirement already satisfied: numba>=0.57.1 in c:\users\admin\miniconda3\lib\site-packages (from stumpy->fiinquantx) (0.61.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\admin\miniconda3\lib\site-packages (from numba>=0.57.1->stumpy->fiinquantx) (0.44.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from FiinQuantX import FiinSession
import pandas as pd
import json 
username = 'DSTC_28@fiinquant.vn'
password = 'Fiinquant0606'

client = FiinSession(username=username, password=password).login()

tickers = client.TickerList(ticker = "VNINDEX")



fi_dict = client.FundamentalAnalysis().get_ratios(
    tickers=tickers,  
    years = [2022,2023,2024,2025],                     
    fields=["ProfitabilityRatio","ValuationRatios"]  
)

# %%
data_vnindex = pd.DataFrame(fi_dict)


data_vnindex = data_vnindex.reset_index(drop=True)
print(data_vnindex.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1559 entries, 0 to 1558
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  1559 non-null   object
#  1   year    1559 non-null   int64
#  2   ratios  1472 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 36.7+ KB
# None

# %%
data_vnindex["ticker"].nunique()
# Out:
# 391

# %%
data_vnindex.head()
# Out:
#   ticker  year                                             ratios
# 0    NO1  2022  {'ProfitabilityRatio': {'EBITMargin': 0.045178...
# 1    NO1  2023  {'ProfitabilityRatio': {'EBITMargin': 0.010272...
# 2    NO1  2024  {'ProfitabilityRatio': {'EBITMargin': 0.023945...
# 3    NO1  2025  {'ProfitabilityRatio': {'EBITMargin': 0.017834...
# 4    SBG  2022  {'ProfitabilityRatio': {'EBITMargin': 0.012855...

# %%
data_vnindex_clean = data_vnindex[data_vnindex["year"] == 2025]
data_vnindex_clean.reset_index(inplace = True)
data_vnindex_cleaned = data_vnindex_clean.drop(["index"], axis =1)
data_vnindex_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  386 non-null    object
#  1   year    386 non-null    int64
#  2   ratios  366 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 9.2+ KB

# %%
data_vnindex_cleaned.dropna(inplace = True)
data_vnindex_cleaned.reset_index()
data_vnindex_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 366 entries, 0 to 385
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  366 non-null    object
#  1   year    366 non-null    int64
#  2   ratios  366 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 11.4+ KB

# %%
data_vnindex_cleaned["ticker"].nunique()
# Out:
# 366

# %%
data_vnindex_cleaned["EBITMargin"] = data_vnindex_cleaned["ratios"].apply(lambda x: x["ProfitabilityRatio"]["EBITMargin"])
data_vnindex_cleaned["ROA"]        = data_vnindex_cleaned["ratios"].apply(lambda x: x["ProfitabilityRatio"]["ROA"])
data_vnindex_cleaned["ROE"]        = data_vnindex_cleaned["ratios"].apply(lambda x: x["ProfitabilityRatio"]["ROE"])
data_vnindex_cleaned["ROIC"]       = data_vnindex_cleaned["ratios"].apply(lambda x: x["ProfitabilityRatio"]["ROIC"])
data_vnindex_cleaned["EPS"]        = data_vnindex_cleaned["ratios"].apply(lambda x: x["ValuationRatios"]["BasicEPS"])
data_vnindex_cleaned["PE"]         = data_vnindex_cleaned["ratios"].apply(lambda x: x["ValuationRatios"]["PriceToEarning"])
data_vnindex_cleaned["PB"]         = data_vnindex_cleaned["ratios"].apply(lambda x: x["ValuationRatios"]["PriceToBook"])


data_vnindex_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 366 entries, 0 to 385
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ticker      366 non-null    object
#  1   year        366 non-null    int64
#  2   ratios      366 non-null    object
#  3   EBITMargin  366 non-null    float64
#  4   ROA         366 non-null    float64
#  5   ROE         366 non-null    float64
#  6   ROIC        366 non-null    float64
#  7   EPS         366 non-null    float64
#  8   PE          366 non-null    float64
#  9   PB          366 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 31.5+ KB

# %%
data_vnindex_cleaned.drop("is_pass", axis =1, inplace = True)
data_vnindex_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 366 entries, 0 to 385
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ticker      366 non-null    object
#  1   year        366 non-null    int64
#  2   ratios      366 non-null    object
#  3   EBITMargin  366 non-null    float64
#  4   ROA         366 non-null    float64
#  5   ROE         366 non-null    float64
#  6   ROIC        366 non-null    float64
#  7   EPS         366 non-null    float64
#  8   PE          366 non-null    float64
#  9   PB          366 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 31.5+ KB

# %%
data_vnindex_cleaned.to_excel("finance data/VNINDEX_Finance.xlsx")

# %%
from FiinQuantX import FiinSession
import pandas as pd
import json 


tickers = client.TickerList(ticker = "UPCOMINDEX")



fi_dict = client.FundamentalAnalysis().get_ratios(
    tickers=tickers,  
    years = [2022,2023,2024,2025],                     
    fields=["ProfitabilityRatio","ValuationRatios"]  
)
data_upcom = pd.DataFrame(fi_dict)
# full_data = pd.concat([full_data, df])


# full_data = full_data.reset_index(drop=True)

data_upcom = data_upcom.reset_index(drop=True)
print(data_upcom.info())
# Out:
# Error fetching ratios for PTM: 'PTM'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2921 entries, 0 to 2920
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  2921 non-null   object
#  1   year    2921 non-null   int64
#  2   ratios  2843 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 68.6+ KB
# None

# %%
data_upcom["ticker"].nunique()
# Out:
# 849

# %%
data_upcom.head()
# Out:
#   ticker  year                                             ratios
# 0    ECO  2023                                                NaN
# 1    ECO  2024  {'ProfitabilityRatio': {'EBITMargin': 0.035021...
# 2    ECO  2025  {'ProfitabilityRatio': {'EBITMargin': 0.038754...
# 3    DDB  2022                                                NaN
# 4    DDB  2023  {'ProfitabilityRatio': {'EBITMargin': 0.058620...

# %%
data_upcom_clean = data_upcom[data_upcom["year"] == 2025]
data_upcom_clean.reset_index(inplace = True)
data_upcom_cleaned = data_upcom_clean.drop(["index"], axis =1)
data_upcom_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  430 non-null    object
#  1   year    430 non-null    int64
#  2   ratios  423 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 10.2+ KB

# %%
data_upcom_cleaned.dropna(inplace = True)
data_upcom_cleaned.reset_index()
data_upcom_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 423 entries, 0 to 429
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  423 non-null    object
#  1   year    423 non-null    int64
#  2   ratios  423 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 13.2+ KB

# %%
data_upcom_cleaned.head()
# Out:
#   ticker  year                                             ratios
# 0    ECO  2025  {'ProfitabilityRatio': {'EBITMargin': 0.038754...
# 1    DDB  2025  {'ProfitabilityRatio': {'EBITMargin': 0.035966...
# 2    HIO  2025  {'ProfitabilityRatio': {'EBITMargin': 0.312409...
# 3    TSA  2025  {'ProfitabilityRatio': {'EBITMargin': 0.054015...
# 4    THM  2025  {'ProfitabilityRatio': {'EBITMargin': 0.089402...

# %%
data_upcom_cleaned["EBITMargin"] = data_upcom_cleaned["ratios"].apply(
    lambda x: x.get("ProfitabilityRatio", {}).get("EBITMargin", None)
)
data_upcom_cleaned["ROA"] = data_upcom_cleaned["ratios"].apply(
    lambda x: x.get("ProfitabilityRatio", {}).get("ROA", None)
)
data_upcom_cleaned["ROE"] = data_upcom_cleaned["ratios"].apply(
    lambda x: x.get("ProfitabilityRatio", {}).get("ROE", None)
)
data_upcom_cleaned["ROIC"] = data_upcom_cleaned["ratios"].apply(
    lambda x: x.get("ProfitabilityRatio", {}).get("ROIC", None)
)
data_upcom_cleaned["EPS"] = data_upcom_cleaned["ratios"].apply(
    lambda x: x.get("ValuationRatios", {}).get("BasicEPS", None)
)
data_upcom_cleaned["PE"] = data_upcom_cleaned["ratios"].apply(
    lambda x: x.get("ValuationRatios", {}).get("PriceToEarning", None)
)
data_upcom_cleaned["PB"] = data_upcom_cleaned["ratios"].apply(
    lambda x: x.get("ValuationRatios", {}).get("PriceToBook", None)
)


data_upcom_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 423 entries, 0 to 429
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ticker      423 non-null    object
#  1   year        423 non-null    int64
#  2   ratios      423 non-null    object
#  3   EBITMargin  414 non-null    float64
#  4   ROA         423 non-null    float64
#  5   ROE         423 non-null    float64
#  6   ROIC        423 non-null    float64
#  7   EPS         423 non-null    float64
#  8   PE          423 non-null    float64
#  9   PB          423 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 36.4+ KB

# %%
data_upcom_cleaned.dropna(inplace = True)
data_upcom_cleaned.reset_index()
data_upcom_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 414 entries, 0 to 429
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ticker      414 non-null    object
#  1   year        414 non-null    int64
#  2   ratios      414 non-null    object
#  3   EBITMargin  414 non-null    float64
#  4   ROA         414 non-null    float64
#  5   ROE         414 non-null    float64
#  6   ROIC        414 non-null    float64
#  7   EPS         414 non-null    float64
#  8   PE          414 non-null    float64
#  9   PB          414 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 35.6+ KB

# %%
data_upcom_cleaned.head()
# Out:
#   ticker  year                                             ratios  EBITMargin  \
# 0    ECO  2025  {'ProfitabilityRatio': {'EBITMargin': 0.038754...    0.038755
# 1    DDB  2025  {'ProfitabilityRatio': {'EBITMargin': 0.035966...    0.035966
# 2    HIO  2025  {'ProfitabilityRatio': {'EBITMargin': 0.312409...    0.312409
# 3    TSA  2025  {'ProfitabilityRatio': {'EBITMargin': 0.054015...    0.054016
# 4    THM  2025  {'ProfitabilityRatio': {'EBITMargin': 0.089402...    0.089403
#
#         ROA       ROE      ROIC         EPS         PE        PB
# 0  0.042113  0.065287  0.052601  734.422678  39.763206  2.541415
# 1  0.007911  0.016925  0.036036  212.663393  47.257781  0.800350
# 2  0.030517  0.059496  0.052140  726.310045  10.915449  0.634241
# 3  0.045127  0.068689  0.075685  739.632383  16.613659  1.172804
# 4  0.038439  0.054302  0.072709  570.229864  15.257005  0.832168

# %%
data_upcom_cleaned.to_excel("finance data/UPCOMINDEX_FinanceData.xlsx")

# %%
tickers = client.TickerList(ticker = "HNXINDEX")



fi_dict = client.FundamentalAnalysis().get_ratios(
    tickers=tickers,  
    years = [2022,2023,2024,2025],                     
    fields=["ProfitabilityRatio","ValuationRatios"]  
)
data_hnx = pd.DataFrame(fi_dict)
# full_data = pd.concat([full_data, df])


# full_data = full_data.reset_index(drop=True)

data_hnx = data_hnx.reset_index(drop=True)
print(data_hnx.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  1209 non-null   object
#  1   year    1209 non-null   int64
#  2   ratios  1201 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 28.5+ KB
# None

# %%
print(data_hnx["ticker"].nunique())
data_hnx.head()
# Out:
# 303
#   ticker  year                                             ratios
# 0    PCH  2022  {'ProfitabilityRatio': {'EBITMargin': 0.112726...
# 1    PCH  2023  {'ProfitabilityRatio': {'EBITMargin': 0.066903...
# 2    PCH  2024  {'ProfitabilityRatio': {'EBITMargin': 0.098836...
# 3    PCH  2025  {'ProfitabilityRatio': {'EBITMargin': 0.114206...
# 4    CAR  2022  {'ProfitabilityRatio': {'EBITMargin': 0.169420...

# %%
data_hnx_clean = data_hnx[data_hnx["year"] == 2025]
data_hnx_clean.reset_index(inplace = True)
data_hnx_cleaned = data_hnx_clean.drop(["index"], axis =1)
data_hnx_cleaned.dropna(inplace = True)
data_hnx_cleaned.reset_index()
data_hnx_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  299 non-null    object
#  1   year    299 non-null    int64
#  2   ratios  299 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 9.3+ KB

# %%
data_hnx_cleaned["EBITMargin"] = data_hnx_cleaned["ratios"].apply(
    lambda x: x.get("ProfitabilityRatio", {}).get("EBITMargin", None)
)
data_hnx_cleaned["ROA"] = data_hnx_cleaned["ratios"].apply(
    lambda x: x.get("ProfitabilityRatio", {}).get("ROA", None)
)
data_hnx_cleaned["ROE"] = data_hnx_cleaned["ratios"].apply(
    lambda x: x.get("ProfitabilityRatio", {}).get("ROE", None)
)
data_hnx_cleaned["ROIC"] = data_hnx_cleaned["ratios"].apply(
    lambda x: x.get("ProfitabilityRatio", {}).get("ROIC", None)
)
data_hnx_cleaned["EPS"] = data_hnx_cleaned["ratios"].apply(
    lambda x: x.get("ValuationRatios", {}).get("BasicEPS", None)
)
data_hnx_cleaned["PE"] = data_hnx_cleaned["ratios"].apply(
    lambda x: x.get("ValuationRatios", {}).get("PriceToEarning", None)
)
data_hnx_cleaned["PB"] = data_hnx_cleaned["ratios"].apply(
    lambda x: x.get("ValuationRatios", {}).get("PriceToBook", None)
)


data_hnx_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ticker      299 non-null    object
#  1   year        299 non-null    int64
#  2   ratios      299 non-null    object
#  3   EBITMargin  299 non-null    float64
#  4   ROA         299 non-null    float64
#  5   ROE         299 non-null    float64
#  6   ROIC        299 non-null    float64
#  7   EPS         299 non-null    float64
#  8   PE          299 non-null    float64
#  9   PB          299 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 25.7+ KB

# %%
data_hnx_cleaned.dropna(inplace = True)
data_hnx_cleaned.reset_index()
data_hnx_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ticker      299 non-null    object
#  1   year        299 non-null    int64
#  2   ratios      299 non-null    object
#  3   EBITMargin  299 non-null    float64
#  4   ROA         299 non-null    float64
#  5   ROE         299 non-null    float64
#  6   ROIC        299 non-null    float64
#  7   EPS         299 non-null    float64
#  8   PE          299 non-null    float64
#  9   PB          299 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 25.7+ KB

# %%
data_hnx_cleaned.head(20)
# Out:
#    ticker  year                                             ratios  \
# 0     PCH  2025  {'ProfitabilityRatio': {'EBITMargin': 0.114206...
# 1     CAR  2025  {'ProfitabilityRatio': {'EBITMargin': 0.080305...
# 2     PPT  2025  {'ProfitabilityRatio': {'EBITMargin': 0.003004...
# 3     VTZ  2025  {'ProfitabilityRatio': {'EBITMargin': 0.043367...
# 4     HMR  2025  {'ProfitabilityRatio': {'EBITMargin': 0.146476...
# 5     AAV  2025  {'ProfitabilityRatio': {'EBITMargin': -0.06369...
# 6     CST  2025  {'ProfitabilityRatio': {'EBITMargin': -0.00080...
# 7     ADC  2025  {'ProfitabilityRatio': {'EBITMargin': 0.034410...
# 8     CAG  2025  {'ProfitabilityRatio': {'EBITMargin': -0.11150...
# 9     AMC  2025  {'ProfitabilityRatio': {'EBITMargin': 0.047578...
# 10    ALT  2025  {'ProfitabilityRatio': {'EBITMargin': 0.023151...
# 11    APS  2025  {'ProfitabilityRatio': {'EBITMargin': -0.49142...
# 12    AME  2025  {'ProfitabilityRatio': {'EBITMargin': 0.037088...
# 13    AMV  2025  {'ProfitabilityRatio': {'EBITMargin': 0.270887...
# 14    API  2025  {'ProfitabilityRatio': {'EBITMargin': 0.165455...
# 15    ARM  2025  {'ProfitabilityRatio': {'EBITMargin': 0.024266...
# 16    ATS  2025  {'ProfitabilityRatio': {'EBITMargin': 0.009659...
# 17    BNA  2025  {'ProfitabilityRatio': {'EBITMargin': 0.058727...
# 18    BKC  2025  {'ProfitabilityRatio': {'EBITMargin': 0.144387...
# 19    BED  2025  {'ProfitabilityRatio': {'EBITMargin': 0.083260...
#
#     EBITMargin       ROA       ROE      ROIC          EPS          PE  \
# 0     0.114207  0.047499  0.051718  0.056418   525.055840   38.281643
# 1     0.080305  0.040634  0.044605  0.056693   461.791220   35.946981
# 2     0.003004  0.018201  0.045754  0.024513   465.335596   30.515611
# 3     0.043367  0.029875  0.099639  0.064501  1188.112909   16.244247
# 4     0.146477  0.061757  0.069394  0.081282   953.713496   13.211515
# 5    -0.063694 -0.012145 -0.015487 -0.016628  -163.784693  -36.022902
# 6    -0.000808 -0.002705 -0.007430 -0.004095  -182.546953  -79.431619
# 7     0.034410  0.069318  0.146410  0.168139  2978.374663    6.446469
# 8    -0.111507 -0.008232 -0.008486 -0.031594   -87.861753  -85.361374
# 9     0.047578  0.058398  0.112873  0.099704  2077.439710    8.664511
# 10    0.023151  0.019812  0.034224  0.034279  1279.429832   10.004456
# 11   -0.491425 -0.056045 -0.056657 -0.065246  -543.192816  -18.777862
# 12    0.037088  0.009887  0.040424  0.053307   503.418014   17.679145
# 13    0.270888  0.036886  0.045023  0.047604   546.047488    3.662685
# 14    0.165455  0.000912  0.002210  0.003725    23.145940  371.555449
# 15    0.024266  0.033286  0.136356  0.124143  1717.784282   16.416497
# 16    0.009659  0.007922  0.008694  0.008931   108.597363  174.037375
# 17    0.058727  0.005736  0.018388  0.037762   300.642735   23.948691
# 18    0.144387  0.133993  0.262672  0.232831  2588.441288   10.392355
# 19    0.083261  0.122945  0.169947  0.139640  2362.746418   10.919496
#
#           PB
# 0   1.944870
# 1   1.645231
# 2   1.378925
# 3   1.717536
# 4   0.904525
# 5   0.560026
# 6   0.638033
# 7   0.986182
# 8   0.722688
# 9   1.001454
# 10  0.338408
# 11  1.097654
# 12  0.701365
# 13  0.167786
# 14  0.817754
# 15  2.148655
# 16  1.506982
# 17  0.450352
# 18  2.550646
# 19  2.021462

# %%
data_hnx_cleaned.to_excel("finance data/HNXINDEX_Finance.xlsx")
